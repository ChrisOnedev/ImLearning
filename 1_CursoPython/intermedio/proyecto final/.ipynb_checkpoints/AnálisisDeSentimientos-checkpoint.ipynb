# %%
import glob #sirve para encontrar archivos dentro de una ruta, con una extension especificada

# Leer DATASET de Train

train_raw = []
print("Leyendo set de entrenamiento...\n")
for filename in glob.glob("./datasets-2026/datasets/train/*.tsv"):
    print(filename)
    print('\t'+' _ _'*25)
    with open(filename,'r', encoding='utf-8') as f:
        for line in f:
            train_raw.append(line)
        
print(f"\tTotal de datos almacenados {len(train_raw)}")
# Out:
# Leyendo set de entrenamiento...
#
# ./datasets-2026/datasets/train\cr.tsv
# 	 _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# ./datasets-2026/datasets/train\es.tsv
# 	 _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# ./datasets-2026/datasets/train\mx.tsv
# 	 _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# ./datasets-2026/datasets/train\pe.tsv
# 	 _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# ./datasets-2026/datasets/train\uy.tsv
# 	 _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# 	Total de datos almacenados 4802

# %%
# Leer DATASET de Prueba

test_raw = []
print("Leyendo set de prueba...\n")
for filename in glob.glob("./datasets-2026/datasets/dev/*.tsv"):
    print(filename)
    print('\t'+' _ _'*25)
    with open(filename,'r', encoding='utf-8') as f:
        for line in f:
            test_raw.append(line)
        
print(f"\tTotal de datos almacenados {len(test_raw)}")
# Out:
# Leyendo set de prueba...
#
# ./datasets-2026/datasets/dev\cr.tsv
# 	 _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# ./datasets-2026/datasets/dev\es.tsv
# 	 _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# ./datasets-2026/datasets/dev\mx.tsv
# 	 _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# ./datasets-2026/datasets/dev\pe.tsv
# 	 _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# ./datasets-2026/datasets/dev\uy.tsv
# 	 _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# 	Total de datos almacenados 2465

# %%
print(train_raw[0])
print(train_raw[200])
print(test_raw[2000])
# Out:
# 809927403615256576	En definitiva! Me quedé sin campo para ir a Tacares, ya que me había mentalizado y ya hasta quería ir #percebe	N
#
# 787887162389766144	@gabrielselva_cr ahí estaba, bueno en el descanso no, me fui a mojar hasta los palcos del frente para hablar con los privados de libertad	NEU
#
# 782960335263244289	@cuervotinelli llegamos a casa !! Duchita y a ponernos cómodos ... Tqm !!, para mi siempre vas a ser el más lindo de todos  !!	P

# %% [markdown]
# # 4.1 Pre-procesamiento con regex

# %%
import re

def extraer_categoria(tweet):
    if re.search('N$', tweet):
        cat = 'negativo'
    if re.search('NEU$', tweet):
        cat = 'neutral'
    if re.search('P$', tweet):
        cat = 'positivo'
    return cat

    
idx = 2004
print(f'Tweet: {train_raw[idx]}')
print(f'Categoria: {extraer_categoria(train_raw[idx])}')
# Out:
# Tweet: 818808229669076992	Recibir una sorpresa inesperada y pasar una noche increible no tiene precio	P
#
# Categoria: positivo

# %% [markdown]
# # 4.2 Eliminar identificador y caracteres no importante
#  #### Patrones de textos a eliminar

# %%
# \d{18}\t    -----> cualquier numerico de 18 caracteres mas tabulacion.
# @\w+        -----> cualquier alfanumerico precedido por una @.
# #\w+        -----> cualquier alfanumerico precedido por una #.
# \w*\d\w*    -----> cualquier alfanumerico con numeros dentro (letra y numeros mezclados).
# [\\¿?¡!$'"&%()*{};@:.,'\/]+     -----> cualquier otro signo especial.
# ['¿?¡!$#\\\/]+

# %%
# los backslashes doble (\\) son usado para que python no lo interprete el \d, \w, etc... como tabulacion, salto de lineas, etc...
def limpiar_tweet(tweet):
    tweet = re.sub("\\d{18}\\t", "", tweet)
    tweet = re.sub("@\\w+", "", tweet)
    tweet = re.sub("#\\w+", "", tweet)
    #tweet = re.sub("\\w*\\d\\w*", "", tweet)  #linea fue comentada porque me elimina los numeros de los tweets
    tweet = re.sub("\n", "", tweet)
    tweet = re.sub("\tN$","", tweet)
    tweet = re.sub("\tNEU$","", tweet)
    tweet = re.sub("\tP$","", tweet)
    tweet = re.sub("[¿?¡!$'#]+", "", tweet) #faltan tratar estos signos: /\|
    tweet.strip()
    tweet.lower()    

    return tweet
    
#print(train_raw[200])
#print(limpiar_tweet(train_raw[200]))

# %%
#Ahora si pre-procesamos los dataset  (Se crea una lista con los Tweets limpios y otra lista solo con las categorias)

x_train = list(map(limpiar_tweet, train_raw)) # train tweets
x_test = list(map(limpiar_tweet, test_raw))   # test tweets

y_train = list(map(extraer_categoria, train_raw)) # train categorias
y_test = list(map(extraer_categoria, test_raw))   # test categorias

# %%
# cantidad de veces que se repite cada palabras en train_raw (una lista)
def dic_stop_words(tweets): #los tweets deben estar en una lista, esto porque que el primer FOR itera una lista y el segundo sobre el String
    #crear el diccionario
    dicc = {}

    for tweet in tweets:
        for word in tweet.split(' '):
            if word in dicc:
                dicc[word]+=1
            else:
                dicc[word]=1

    # ORDENAR de forma descendiente (Desde las palabras mas comunes a las menos comunes)
    dicc_sorted = {}
    for k, v in sorted(dicc.items(), key=lambda item: item[1], reverse=True):
        dicc_sorted[k]=v

    return dicc_sorted

# %%
#lista de palabras Stop_words (palabra que no agregan valor porque son conectores, preposiciones, etc...)

stop_words_dic = dic_stop_words(x_train)
stop_words = list(stop_words_dic.keys())[0:39]
print(stop_words)
# Out:
# ['', 'de', 'que', 'y', 'a', 'la', 'no', 'me', 'el', 'en', 'es', 'un', 'lo', 'mi', 'por', 'se', 'con', 'para', 'los', 'pero', 'las', 'una', 'te', 'ya', 'si', 'yo', 'como', 'al', 'del', 'muy', 'más', 'tu', 'tengo', 'No', 'todo', 'q', 'porque', 'estoy', 'le']

# %%
# Ahora crear un diccionario para comentarios positivos, neutral y negativos. No incluir palabras en "Stop_word"

# tweets --> texto a analizar (lista de los tweets limpios)
# cats --> lista que contiene solo las categorias (lista de las categorias limpias)
# categoria --> La unica categoria que quiero analizar
# stopwords --> parabras qu quiero que no sean tomadas en cuenta

def dic_palabras_comunes(tweets, cats, categoria, stopwords):

    dicc = {}
    for tweet, cat in zip(tweets, cats):
        if cat == categoria:
            for word in tweet.split(' '):
                if word not in stopwords:
                    if word in dicc:
                        dicc[word]+=1
                    else:
                        dicc[word]=1
    
    # Retorna un dic, pero ordenado de mayor a menor
    dicc_sorted={}
    for k, v in sorted(dicc.items(), key=lambda item: item[1], reverse=True):
        dicc_sorted[k]=v

    return dicc_sorted


positivo_dicc = dic_palabras_comunes(x_train, y_train, 'positivo', stop_words)
neutral_dicc = dic_palabras_comunes(x_train, y_train, 'neutral', stop_words)
negativo_dicc = dic_palabras_comunes(x_train, y_train, 'negativo', stop_words)

print(neutral_dicc)
#print(x_train)
# Out:
# {'o': 62, 'solo': 53, 'son': 52, 'soy': 51, 'Yo': 50, 'eso': 48, 'quiero': 47, 'está': 47, 'día': 47, 'esta': 46, 'ver': 45, 'ser': 44, 'Y': 43, 'hacer': 42, 'así': 42, 'Pero': 42, 'hay': 42, 'mejor': 42, 'voy': 42, 'año': 42, 'todos': 42, 'Si': 41, 'mis': 41, 'cuando': 41, 'vez': 39, 'igual': 39, 'ahora': 39, 'ni': 37, 'El': 36, 'bueno': 36, 'La': 36, ',': 36, 'su': 34, 'algo': 33, 'En': 32, 'bien': 32, 'nos': 31, 'Ya': 31, 'qué': 30, 'Lo': 30, 'Es': 29, 'he': 29, '-': 29, 'jaja': 28, 'menos': 28, 'siempre': 28, 'Me': 28, 'desde': 28, 'va': 27, 'cosas': 27, 'hace': 27, 'días': 27, 'mañana': 25, 'nada': 25, 'Hoy': 25, '.': 25, 'este': 25, 'tan': 25, 'ir': 25, 'tiene': 25, 'fue': 25, 'nuevo': 24, 'hasta': 24, 'Mi': 24, 'creo': 24, 'A': 24, 'tener': 23, 'vida': 23, 'cada': 23, 'ha': 23, 'dos': 23, 'era': 23, 'Hola': 23, 'mismo': 23, 'Que': 23, 'hoy': 22, '3': 22, 'estar': 22, 'puedo': 22, 'sin': 22, '...': 22, 'años': 21, 'gracias': 21, 'sus': 21, 'sea': 21, 'jajaja': 20, 'mas': 20, 'semana': 20, 'mucho': 20, 'veo': 20, 'noche': 20, 'quien': 20, 'mal': 19, 'feliz': 19, 'uno': 18, 'Por': 18, 'gente': 18, 'puede': 18, 'pues': 18, 'ese': 17, 'nunca': 17, 'también': 17, 'buena': 17, 'alguien': 17, 'espero': 17, 'casa': 16, 'toda': 16, 'Estoy': 16, 'aquí': 16, 'otro': 16, 'había': 16, 'sé': 16, 'estaba': 15, 'final': 15, 'les': 15, 'esos': 15, 'primer': 15, 'seguro': 15, 'veces': 15, 'buen': 15, 'ayer': 15, 'De': 15, 'Quiero': 14, 'sólo': 14, 'vi': 14, '2': 14, 'después': 14, 'esa': 14, 'tienes': 14, 'aún': 14, 'paso': 14, 'será': 14, 'viene': 14, 'foto': 14, 'pasa': 14, 'queda': 13, 'están': 13, 'fin': 13, 'único': 13, 'favor': 13, 'mí': 13, 're': 13, 'salir': 12, 'van': 12, 'claro': 12, 'dormir': 12, 'Gracias': 12, 'donde': 12, 'no,': 12, 'amigo': 12, 'vamos': 12, 'extraño': 12, '10': 12, 'otra': 12, 'haga': 12, 'antes': 12, 'dice': 12, 'Saludos': 12, 'Tengo': 11, 'mamá': 11, 'Cuando': 11, 'casi': 11, 'parte': 11, 'puse': 11, 'normal': 11, 'tipo': 11, 'hablar': 11, 'sabe': 11, 'Un': 11, 'algún': 11, 'trabajo': 11, 'sí': 11, 'da': 11, 'amor': 11, 'x': 11, 'asi': 11, 'estos': 11, 'eres': 11, '—': 11, 'nueva': 10, 'unas': 10, 'horas': 10, 'haciendo': 10, 'pasado': 10, 'hola': 10, 'ella': 10, 'fui': 10, 'pasar': 10, 'navidad': 10, 'trabajar': 10, 'tiempo': 10, 'familia': 10, 'Se': 10, 'cambiar': 10, 'Bueno': 10, 'primera': 10, 'hacen': 10, 'cuenta': 10, 'quería': 10, 'unos': 10, 'estás': 10, 'verdad': 10, 'dia': 10, '20': 10, 'saber': 10, 'única': 10, 'Te': 10, 'mail': 10, 'luego': 9, 'serio': 9, 'Qué': 9, '4': 9, 'muchas': 9, 'amigos': 9, 'descanso': 9, 'entonces': 9, 'dijo': 9, 'llegar': 9, 'lindo': 9, '5': 9, 'quiere': 9, 'visto': 9, 'mejores': 9, 'poner': 9, 'dicen': 9, 'Ahora': 9, 'estaré': 9, 'fuera': 9, 'cómo': 9, 'd': 9, 'bueno,': 9, 'gran': 9, 'tal': 9, 'tú': 9, 'entre': 9, 'contigo': 9, 'somos': 9, 'Al': 9, 'necesito': 9, 'último': 9, 'falta': 9, 'buenos': 9, 'vas': 9, 'examen': 8, 'ah': 8, 'Como': 8, 'hago': 8, 'nadie': 8, 'momento': 8, 'hora': 8, 'pueden': 8, 'tanto': 8, 'saben': 8, 'Mañana': 8, '7': 8, 'otros': 8, 'temporada': 8, 'Sí,': 8, 'Aunque': 8, '8': 8, 'segunda': 8, 'llevo': 8, 'dias': 8, 'cosa': 8, 'jajajaja': 8, 'diferente': 8, 'poquito': 8, 'viernes': 8, 'tampoco': 8, 'aunque': 8, 'puedes': 8, 'bien,': 8, '+': 8, 'sido': 8, 'pa': 8, 'Hay': 8, 'sí,': 8, 'cara': 8, 'sueño': 8, 'bonita': 8, 'todas': 8, 'Para': 7, 'ahí': 7, 'dar': 7, 'juntos': 7, 'próximo': 7, 'Esta': 7, 'Solo': 7, 'ti': 7, 'tenemos': 7, 'Eso': 7, 'comer': 7, 'debe': 7, 'largo': 7, 'tenía': 7, 'amiga': 7, 'misma': 7, '•': 7, 'si,': 7, 'hecho': 7, 'buenas': 7, 'Necesito': 7, 'iba': 7, 'acá': 7, 'acabo': 7, 'estas': 7, 'ganas': 7, 'bonito': 7, 'Todo': 7, 'agua': 7, 'tambien': 7, 'sabes': 7, 'usuario': 7, 'Bueno,': 7, 'Con': 7, 'decir': 7, 'Lima': 7, 'lugar': 7, 'sería': 7, 'recién': 7, 'Siempre': 7, 'apenas': 6, 'felices': 6, 'Ojalá': 6, 'sino': 6, 'culpa': 6, 'vivir': 6, 'Hola,': 6, 'tercer': 6, 'O': 6, 'última': 6, 'esto': 6, 'deja': 6, 'cine': 6, ' ...
