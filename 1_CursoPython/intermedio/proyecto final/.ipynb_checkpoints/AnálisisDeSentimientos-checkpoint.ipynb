# %%
import glob #sirve para encontrar archivos dentro de una ruta, con una extension especificada

# Leer DATASET de Train

train_raw = []
print("Leyendo set de entrenamiento...\n")
for filename in glob.glob("./datasets-2026/datasets/train/*.tsv"):
    print(filename)
    print('\t'+' _ _'*25)
    with open(filename,'r', encoding='utf-8') as f:
        for line in f:
            train_raw.append(line)
        
print(f"\tTotal de datos almacenados {len(train_raw)}")

# %%
# Leer DATASET de Prueba

test_raw = []
print("Leyendo set de prueba...\n")
for filename in glob.glob("./datasets-2026/datasets/dev/*.tsv"):
    print(filename)
    print('\t'+' _ _'*25)
    with open(filename,'r', encoding='utf-8') as f:
        for line in f:
            test_raw.append(line)
        
print(f"\tTotal de datos almacenados {len(test_raw)}")

# %%
print(train_raw[25])
print(train_raw[200])
print(test_raw[2000])
# Out:
# 786728406633156608	Mañana tengo examen de química e inglés, y aquí estoy acostada, con el celular, conciente de que no se ni que temas me entran	N
#
# 787887162389766144	@gabrielselva_cr ahí estaba, bueno en el descanso no, me fui a mojar hasta los palcos del frente para hablar con los privados de libertad	NEU
#
# 782960335263244289	@cuervotinelli llegamos a casa !! Duchita y a ponernos cómodos ... Tqm !!, para mi siempre vas a ser el más lindo de todos  !!	P

# %% [markdown]
# # 4.1 Pre-procesamiento con regex

# %%
import re

def extraer_categoria(tweet):
    if re.search('N$', tweet):
        cat = 'Negativo'
    if re.search('NEU$', tweet):
        cat = 'Neutral'
    if re.search('P$', tweet):
        cat = 'Positivo'
    return cat

    
idx = 2004
print(f'Tweet: {train_raw[idx]}')
print(f'Categoria: {extraer_categoria(train_raw[idx])}')

# %% [markdown]
# # 4.2 Eliminar identificador y caracteres no importante
#  #### Patrones de textos a eliminar

# %%
# \d{18}\t    -----> cualquier numerico de 18 caracteres mas tabulacion.
# @\w+        -----> cualquier alfanumerico precedido por una @.
# #\w+        -----> cualquier alfanumerico precedido por una #.
# \w*\d\w*    -----> cualquier alfanumerico con numeros dentro (letra y numeros mezclados).
# [\\'¿?¡!$'"&%()*{};@:.,'\/]+     -----> cualquier otro signo especial.

# %%
def dic_stop_word(tweets): #los tweets deben estar en una lista, esto para que el primer FOR itere sobre letras por letras
    #crear el diccionario
    dicc = {}

    for tweet in tweets:
        for word in tweet.split(' '):
            if word in dicc:
                dicc[word]+=1
            else:
                dicc[word]=1

    # ORDENAR de forma descendiente (De las palabras mas comunes a las menos comunes)
    dicc_sorted = {}
    for k, v in sorted(dicc.items(), key=lambda item: item[1], reverse=True):
        dicc_sorted[k]=v

    return dicc_sorted

# %%
print(train_raw[20])

# %%
l = dic_stop_word([train_raw[20]])

print(l)
